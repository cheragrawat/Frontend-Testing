# %% [markdown]
# # **Frontend Testing Assignment**

# %% [markdown]
# **Name : Chirag Kailashbhai Rawat**

# %% [markdown]
# 1. **Use tools like JMeter or Gatling to perform load testing on a web
# application and analyze the results to identify performance bottlenecks.?**

# %% [markdown]
# # JMeter Performance Testing Assignment
#
# ### Student Name: Cherag Rawat
#
# This notebook contains:
# - JMeter Test Plan (.jmx)
# - Screenshots of JMeter setup
# - Analysis of performance test results

# %% [markdown]
# ![test plan.png](data:image/png;base64,...)

# %% [markdown]
# ![GUI.png](data:image/png;base64,...)

# %% [markdown]
# ![http req.png](data:image/png;base64,...)

# %% [markdown]
# ![tree.png](data:image/png;base64,...)

# %% [markdown]
# ![result.png](data:image/png;base64,...)
